# %%
import pandas as pd
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import os

# %%
# 主資料夾路徑
main_folder_path = "D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論"
output_folder_path = os.path.join(main_folder_path, "wordcloud")

# 創建文字雲圖片儲存資料夾（如果不存在）
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# 確認字體路徑是否正確
font_path = "C:/Windows/Fonts/msjh.ttc"  # Windows系統的字體路徑
if not os.path.exists(font_path):
    raise FileNotFoundError(f"字體文件未找到: {font_path}")

# 用於儲存所有酒吧文字雲的資料
wordcloud_data = []

# 遍歷主資料夾內的所有子資料夾
for root, dirs, files in os.walk(main_folder_path):
    for file in files:
        # 確認檔案是否為 CSV
        if file.endswith(".csv"):
            file_path = os.path.join(root, file)
            print(f"處理檔案: {file_path}")

            # 嘗試檢測編碼並讀取文件
            try:
                with open(file_path, 'rb') as f:
                    result = chardet.detect(f.read())
                encoding = result['encoding']
                print(f"檢測到的編碼: {encoding}")

                df = pd.read_csv(file_path, encoding=encoding)
            except Exception as e:
                print(f"無法讀取檔案 {file_path}，錯誤: {e}")
                continue

            # 檢查是否包含 "評論" 欄位
            if '評論' not in df.columns:
                print(f"檔案 {file_path} 不包含 '評論' 欄位，跳過")
                continue

            # 合併評論
            all_comments = " ".join(df['評論'].dropna().astype(str))

            # 創建文字雲
            wordcloud = WordCloud(
                width=800,
                height=400,
                background_color='white',
                font_path=font_path,
                max_words=100,
                contour_color='steelblue'
            ).generate(all_comments)

            # 取得酒吧名字作為圖片名稱（移除 .csv 副檔名）
            bar_name = os.path.splitext(file)[0]

            # 儲存文字雲圖片到 wordcloud 資料夾
            output_image_path = os.path.join(output_folder_path, f"{bar_name}.png")
            wordcloud.to_file(output_image_path)
            print(f"已儲存文字雲圖片至: {output_image_path}")

            # 儲存酒吧的文字雲數據到列表
            wordcloud_data.append({
                "酒吧名稱": bar_name,
                "文字雲關鍵字": wordcloud.words_
            })

# 將所有酒吧的文字雲關鍵字數據儲存到一個 CSV 檔案
output_csv_path = os.path.join(main_folder_path, "wordcloud.csv")
wordcloud_df = pd.DataFrame(wordcloud_data)
wordcloud_df["文字雲關鍵字"] = wordcloud_df["文字雲關鍵字"].apply(lambda x: str(x))  # 將字典轉為字串
wordcloud_df.to_csv(output_csv_path, index=False, encoding='utf-8-sig')
print(f"所有酒吧的文字雲關鍵字數據已儲存至: {output_csv_path}")

# 檢測沒有文字雲圖片的店家
csv_files = [os.path.splitext(file)[0] for root, dirs, files in os.walk(main_folder_path) for file in files if file.endswith(".csv")]
image_files = [os.path.splitext(file)[0] for file in os.listdir(output_folder_path) if file.endswith(".png")]

missing_images = [bar for bar in csv_files if bar not in image_files]

if missing_images:
    print("以下店家沒有生成文字雲圖片:")
    for bar in missing_images:
        print(bar)
else:
    print("所有店家都已生成文字雲圖片。")
# Out:
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud.csv
# 檢測到的編碼: UTF-8-SIG
# 檔案 D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud.csv 不包含 '評論' 欄位，跳過
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\23 Music Room.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\23 Music Room.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\50_45 WINEHAUS 伴瓶酒葡萄酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\50_45 WINEHAUS 伴瓶酒葡萄酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\7th Japanese Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\7th Japanese Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\8528 Music Bar 不限時調酒暢飲.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\8528 Music Bar 不限時調酒暢飲.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\85基地Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\85基地Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\88 sports bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\88 sports bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\A Train Leads The Way To Jazz.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\A Train Leads The Way To Jazz.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\ABV Bar & Kitchen 日式居酒館 中山區居酒屋 中山站美食 大阪燒 廣島燒 宵夜 精釀啤酒 串燒炸物烤物.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\ABV Bar & Kitchen 日式居酒館 中山區居酒屋 中山站美食 大阪燒 廣島燒 宵夜 精釀啤酒 串燒炸物烤物.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Aimas talking bar ｜中山區夜深酒吧｜.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Aimas talking bar ｜中山區夜深酒吧｜.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\all_stores.csv
# 檢測到的編碼: UTF-8-SIG
# 檔案 D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\all_stores.csv 不包含 '評論' 欄位，跳過
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Arno bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Arno bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Authentic Bar小谷 -Bar Otani-【香水類不可】【正統酒吧】.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Authentic Bar小谷 -Bar Otani-【香水類不可】【正統酒吧】.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\B52.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\B52.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bacchus Lounge Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bacchus Lounge Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\BAR ACE.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BAR ACE.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar Amis.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Amis.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar ansleep Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar ansleep Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar Freedom.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Freedom.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar Genao.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Genao.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\BAR MOSAIC.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BAR MOSAIC.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\BAR NiNE 日本語English okのショットバー.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BAR NiNE 日本語English okのショットバー.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar Seed Taipei《調酒酒吧》中山區英式bar｜熱門｜深夜酒吧｜酒吧推薦｜氣氛酒吧｜捷運酒吧｜客製化調酒.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Seed Taipei《調酒酒吧》中山區英式bar｜熱門｜深夜酒吧｜酒吧推薦｜氣氛酒吧｜捷運酒吧｜客製化調酒.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar Soft Cure.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Soft Cure.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar Vintage.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Vintage.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar VIP.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar VIP.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar 千華.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar 千華.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\BAR 忠 Chu.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BAR 忠 Chu.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bar 澤山.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar 澤山.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\BAR1000.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BAR1000.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\BLUE FISH BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BLUE FISH BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Blush bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Blush bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\bochibochi bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\bochibochi bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Bridge.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bridge.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\C PARK Re_Creation by A Train.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\C PARK Re_Creation by A Train.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Cheers.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Cheers.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Cinnamon bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Cinnamon bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Clean Rose.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Clean Rose.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Continue_ Gaming Bar電玩餐酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Continue_ Gaming Bar電玩餐酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Crafted Beer & Co. 精釀啤酒屋.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Crafted Beer & Co. 精釀啤酒屋.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Dimple 酒窩 Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Dimple 酒窩 Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Eagle bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Eagle bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\From A.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\From A.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\GDGaGa吉蒂卡卡酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\GDGaGa吉蒂卡卡酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Ginza Sakoh 銀座酒向.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Ginza Sakoh 銀座酒向.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Green Door Bar 綠門 老酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Green Door Bar 綠門 老酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Hanes Singing Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Hanes Singing Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Honn Bar 酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Honn Bar 酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\HW Lounge｜Bar｜Coffee｜電影主題調酒｜Cigar 獨立雪茄室.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\HW Lounge｜Bar｜Coffee｜電影主題調酒｜Cigar 獨立雪茄室.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\INGE'S Bar & Grill 台北萬豪酒店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\INGE'S Bar & Grill 台北萬豪酒店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\iSLA #612 _ 中山區酒吧・餐酒館 _ 原 Tropicana Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\iSLA #612 _ 中山區酒吧・餐酒館 _ 原 Tropicana Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\J&J 複合式酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\J&J 複合式酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Join酒隱Lounge Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Join酒隱Lounge Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\La Habana Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\La Habana Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\La Salle 森酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\La Salle 森酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\La · Lune.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\La · Lune.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Lady Darts 飛鏢_BAR_聚會_運動.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Lady Darts 飛鏢_BAR_聚會_運動.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Leone Restaurant & Bar｜台北餐酒館 ｜酒吧｜ 餐廳 ｜餐酒館 ｜中山美食｜中山餐酒館｜ 林森北酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Leone Restaurant & Bar｜台北餐酒館 ｜酒吧｜ 餐廳 ｜餐酒館 ｜中山美食｜中山餐酒館｜ 林森北酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Lobby Lounge @台北萬豪酒店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Lobby Lounge @台北萬豪酒店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Lounge Vino.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Lounge Vino.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Lux Terrace BAR 中山區 林森店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Lux Terrace BAR 中山區 林森店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\M Club.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\M Club.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\MADE Taipei-東區人氣酒吧_cp酒吧_必去酒吧_忠孝復興人氣酒吧_特色酒吧_熱門酒吧_餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\MADE Taipei-東區人氣酒吧_cp酒吧_必去酒吧_忠孝復興人氣酒吧_特色酒吧_熱門酒吧_餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Matt Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Matt Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Mingle Bar&Bistro.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Mingle Bar&Bistro.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Mini Base小喬室.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Mini Base小喬室.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Mirufi Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Mirufi Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\MUD Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\MUD Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Nep. Lounge Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Nep. Lounge Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Nine to Night Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Nine to Night Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\No.19 Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\No.19 Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Oleno Bar（hiphop）林森店 ｜中山區 林森北路 chill vibes.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Oleno Bar（hiphop）林森店 ｜中山區 林森北路 chill vibes.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\ONE 9 bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\ONE 9 bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Park90, Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Park90, Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\PATINA Lounge.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\PATINA Lounge.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Poetry 如詩｜大直早午餐、餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Poetry 如詩｜大直早午餐、餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\RK Darts Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\RK Darts Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\SecretBistro秘密小酒館 台北餐酒館｜必吃餐酒館推薦 熱門創意調酒 網美網紅餐廳優惠 特色美食料理 人氣IG打卡 不限時餐廳 聚會包場酒吧 網友好評派對小酌 慶生約會首選 調酒雞尾酒 台北中山區 僅此一家 別無分店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\SecretBistro秘密小酒館 台北餐酒館｜必吃餐酒館推薦 熱門創意調酒 網美網紅餐廳優惠 特色美食料理 人氣IG打卡 不限時餐廳 聚會包場酒吧 網友好評派對小酌 慶生約會首選 調酒雞尾酒 台北中山區 僅此一家 別無分店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Shisha屋Match林森唱歌店台北高cp值暢飲水煙館_有骰盅鹹酥雞披薩Hookah喝到飽KTV值得推薦的非酒吧Bar炸物餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Shisha屋Match林森唱歌店台北高cp值暢飲水煙館_有骰盅鹹酥雞披薩Hookah喝到飽KTV值得推薦的非酒吧Bar炸物餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\SHOT 班.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\SHOT 班.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\sneaKOut BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\sneaKOut BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Soshow Bar & Restaurant.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Soshow Bar & Restaurant.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Sugar Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Sugar Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Super 346啤酒文創館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Super 346啤酒文創館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Swing piano bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Swing piano bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\T.R Bar & Kitchen.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\T.R Bar & Kitchen.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\TABOO CLUB.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\TABOO CLUB.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\The Herbal Bar 香草窗.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The Herbal Bar 香草窗.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\The Open Door.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The Open Door.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\The Pub.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The Pub.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Upsilon水煙調酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Upsilon水煙調酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Via24 Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Via24 Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\VINDEX 雅粹 │ 中山門市-微醺概念Bar、葡萄酒專賣 (預約制).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\VINDEX 雅粹 │ 中山門市-微醺概念Bar、葡萄酒專賣 (預約制).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Voice Long Play Bar 聲聲不息酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Voice Long Play Bar 聲聲不息酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Waroom Bar 暖閣 彩虹 台北六條通酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Waroom Bar 暖閣 彩虹 台北六條通酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\Welina卡啦OK酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Welina卡啦OK酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\WXYZ Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\WXYZ Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\XXXLab 解憂吧 Cocktail Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\XXXLab 解憂吧 Cocktail Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\一時無酉 abvless （預約制 Reservation only）.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\一時無酉 abvless （預約制 Reservation only）.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\五號酒吧 No5 Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\五號酒吧 No5 Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\台北中山意舍酒店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\台北中山意舍酒店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\噶瑪蘭威士忌酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\噶瑪蘭威士忌酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\圓山大飯店-覓到酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\圓山大飯店-覓到酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\塵世酒吧 SENSE PUB.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\塵世酒吧 SENSE PUB.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\壹樓．臺北 1st. Floor Bar Taipei 壹樓酒吧．臺北壹號店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\壹樓．臺北 1st. Floor Bar Taipei 壹樓酒吧．臺北壹號店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\大倉久和飯店 珍珠酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\大倉久和飯店 珍珠酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\小後苑Backyard Jr. (大直Dazhi).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\小後苑Backyard Jr. (大直Dazhi).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\小酒 sake bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\小酒 sake bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\布娜飛小酒館中山店Bravocafe draftbeer.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\布娜飛小酒館中山店Bravocafe draftbeer.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\布娜飛紅酒餐酒館Bravo Wine.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\布娜飛紅酒餐酒館Bravo Wine.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\干啦！ music bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\干啦！ music bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\微醺・中山 清酒餐酒館｜中山區餐酒館｜行天宮餐酒館｜中山區約會小酌聚餐｜中山區午晚餐宵夜推薦｜中山區午餐定食推薦.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\微醺・中山 清酒餐酒館｜中山區餐酒館｜行天宮餐酒館｜中山區約會小酌聚餐｜中山區午晚餐宵夜推薦｜中山區午餐定食推薦.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\微醺飛鏢酒吧｜台北中山區 條通酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\微醺飛鏢酒吧｜台北中山區 條通酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\心白.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\心白.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\找小山 BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\找小山 BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\暖閣仕女飛鏢酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\暖閣仕女飛鏢酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\桂公子酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\桂公子酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\梵谷 Lounge Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\梵谷 Lounge Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\特區Pub.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\特區Pub.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\當吧PAWN BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\當吧PAWN BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\石洞PUB(My Place).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\石洞PUB(My Place).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\碧耳貓 BeerCat.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\碧耳貓 BeerCat.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\秘室Chamber.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\秘室Chamber.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\糖葫蘆小酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\糖葫蘆小酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\紙醉金迷 Relax Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\紙醉金迷 Relax Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\老吧 Bar Aged.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\老吧 Bar Aged.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\老大直 Old Town Bar 餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\老大直 Old Town Bar 餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\臺日交流Cafe & Bar Kiseki.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\臺日交流Cafe & Bar Kiseki.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\莫內 Lounge bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\莫內 Lounge bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\藤 Restaurant & Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\藤 Restaurant & Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\說故事創義麵餐酒館-中山必去餐酒館_義大利麵_餐酒館推薦_聚餐餐廳_酒吧推薦_宵夜推薦_深夜酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\說故事創義麵餐酒館-中山必去餐酒館_義大利麵_餐酒館推薦_聚餐餐廳_酒吧推薦_宵夜推薦_深夜酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\達文西視覺酒吧 Da Vinci Lounge Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\達文西視覺酒吧 Da Vinci Lounge Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\酒寨Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒寨Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\酒點見talking bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒點見talking bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\釂JIAO Taipei【中山區水煙餐酒館】特色酒吧｜高級餐酒館｜人氣酒吧｜人氣調酒｜精緻酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\釂JIAO Taipei【中山區水煙餐酒館】特色酒吧｜高級餐酒館｜人氣酒吧｜人氣調酒｜精緻酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\陽光美酒薈.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\陽光美酒薈.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\隱侍餐酒館(台北大直店) The Samurai Bistro.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\隱侍餐酒館(台北大直店) The Samurai Bistro.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\飛喬 x 加州陽光 LiveMusic Bar 音樂酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\飛喬 x 加州陽光 LiveMusic Bar 音樂酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中山區 酒吧\麗濱美式酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\麗濱美式酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\2020 cocktail&drinks.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\2020 cocktail&drinks.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\89 Loop Sports Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\89 Loop Sports Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\AL CICCHETTO HUASHAN BISTRO義麵坊華山小酒吧(餐酒館｜義大利麵｜調酒｜生啤酒｜葡萄酒).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\AL CICCHETTO HUASHAN BISTRO義麵坊華山小酒吧(餐酒館｜義大利麵｜調酒｜生啤酒｜葡萄酒).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\all_stores.csv
# 檢測到的編碼: UTF-8-SIG
# 檔案 D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\all_stores.csv 不包含 '評論' 欄位，跳過
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Another Brick.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Another Brick.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\ASA.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\ASA.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Azeroth Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Azeroth Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\B Line by A Train.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\B Line by A Train.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\BAR FEST.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BAR FEST.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Bar M.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar M.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Bar THY 桃花源.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar THY 桃花源.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Bertha Irish Bar _ 公館酒吧 愛爾蘭 BAR 啤酒 調酒推薦 人氣酒吧推薦.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bertha Irish Bar _ 公館酒吧 愛爾蘭 BAR 啤酒 調酒推薦 人氣酒吧推薦.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Bouti Bar Taipei - 璞邸旅店1F _北車精釀_瓶裝啤酒.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bouti Bar Taipei - 璞邸旅店1F _北車精釀_瓶裝啤酒.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\BUDA 好運豬酒吧Taproom & Wine.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BUDA 好運豬酒吧Taproom & Wine.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Buono 享味生活 (台電大樓 師大 葡萄酒 精釀啤酒 自然葡萄酒 ).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Buono 享味生活 (台電大樓 師大 葡萄酒 精釀啤酒 自然葡萄酒 ).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Hello Taipei Sport Space.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Hello Taipei Sport Space.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\HI NE NI.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\HI NE NI.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\HIPP 喜寶棧 - 咖啡酒館 & 貓旅館 每天營業 月底店休11月25_26日 CAFE BAR & CAT HOTEL.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\HIPP 喜寶棧 - 咖啡酒館 & 貓旅館 每天營業 月底店休11月25_26日 CAFE BAR & CAT HOTEL.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Incoming bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Incoming bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Jolly 手工釀啤 酒泰食餐廳-衡陽店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Jolly 手工釀啤 酒泰食餐廳-衡陽店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\JupJup 精釀生啤餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\JupJup 精釀生啤餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Learn Bar 學吧精釀.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Learn Bar 學吧精釀.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\LOCA Coffee&Wine.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\LOCA Coffee&Wine.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Miss Strega Cafe & Bar 義大利女巫咖啡酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Miss Strega Cafe & Bar 義大利女巫咖啡酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Mixtio 秘地｜咖啡.排餐.啤酒.餐酒館.商務.辦公｜不限時插座.包廂.76人場地租借.中正區美食.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Mixtio 秘地｜咖啡.排餐.啤酒.餐酒館.商務.辦公｜不限時插座.包廂.76人場地租借.中正區美食.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\NAKA Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\NAKA Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\No.82 Drawing room(82號客廳）.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\No.82 Drawing room(82號客廳）.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Power Beef 日式烤牛肉飯小酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Power Beef 日式烤牛肉飯小酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Prozac Balcony 百憂解陽台.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Prozac Balcony 百憂解陽台.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\R8 Metro Bar - R8捷運輕食吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\R8 Metro Bar - R8捷運輕食吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\RainbowGym 彩虹健身房 公館健身房 健身酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\RainbowGym 彩虹健身房 公館健身房 健身酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Revolver.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Revolver.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\SipSip Bar & Restaurant.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\SipSip Bar & Restaurant.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Staff Only Club.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Staff Only Club.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\SUNMAI BAR 中正 R8.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\SUNMAI BAR 中正 R8.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Taipei Alcohol Exchange Kaffe 台北酒精交易所.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Taipei Alcohol Exchange Kaffe 台北酒精交易所.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\The Misanthrope Society 厭世會社｜Cafe Bistro Bookstore.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The Misanthrope Society 厭世會社｜Cafe Bistro Bookstore.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\The Primrose(Bar春花).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The Primrose(Bar春花).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\The Shrine.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The Shrine.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Whisky Salon (台灣第一家Japanese Whisky Bar).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Whisky Salon (台灣第一家Japanese Whisky Bar).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\WHOOSAH..csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\WHOOSAH..png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\Wink1號店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Wink1號店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\メロメロ MeloMelo Cafe&bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\メロメロ MeloMelo Cafe&bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\三重奏比特司 Trio bitters.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\三重奏比特司 Trio bitters.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\二丁目 - Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\二丁目 - Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\作 SAKU by necoichi.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\作 SAKU by necoichi.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\公館45 Old Bar Coffee.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\公館45 Old Bar Coffee.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\劑院 Dose cuisine & malt.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\劑院 Dose cuisine & malt.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\北風北_古亭酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\北風北_古亭酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\台北喜來登大飯店 - 大廳酒吧 The Lounge.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\台北喜來登大飯店 - 大廳酒吧 The Lounge.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\喜咧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\喜咧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\土貓商號 Turkish Kedi.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\土貓商號 Turkish Kedi.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\小公館咖啡 精釀啤酒.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\小公館咖啡 精釀啤酒.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\小地方seams.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\小地方seams.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\小屋shisha.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\小屋shisha.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\怪咖屋THE WACKO HOUSE Brunch & Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\怪咖屋THE WACKO HOUSE Brunch & Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\拉圖爾精釀柴燒餐廳 La Tour Craft Beer & Wood Grill.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\拉圖爾精釀柴燒餐廳 La Tour Craft Beer & Wood Grill.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\渣男Taiwan Bistro古亭四渣.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\渣男Taiwan Bistro古亭四渣.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\澗面小酒館 Bar & Bistro.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\澗面小酒館 Bar & Bistro.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\無意義.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\無意義.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\燕子愛紅酒Yan's Wine.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\燕子愛紅酒Yan's Wine.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\窖父 Hide Out.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\窖父 Hide Out.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\純愛小吃部.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\純愛小吃部.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\維都餐酒館｜啤酒｜調酒｜生啤塔（公館店）.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\維都餐酒館｜啤酒｜調酒｜生啤塔（公館店）.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\老同安小酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\老同安小酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\老屁股.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\老屁股.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\艾萃咖啡 VR BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\艾萃咖啡 VR BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\草頭西.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\草頭西.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\華山町餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\華山町餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\西門暖閣餐酒館／waroom Restaurant Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\西門暖閣餐酒館／waroom Restaurant Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\言文字 Emoji Cafe & Bar｜數位工作者聚落 The Digital Tribe.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\言文字 Emoji Cafe & Bar｜數位工作者聚落 The Digital Tribe.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\酒販角落.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒販角落.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\金色三麥.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\金色三麥.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\錢記披薩 cash's bar & pizza.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\錢記披薩 cash's bar & pizza.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\防空洞 bomb shelter 華山店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\防空洞 bomb shelter 華山店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\離騷 Bar & Bistro.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\離騷 Bar & Bistro.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\中正區 酒吧\黑帽爵士咖啡酒吧 BlackHatJazz cafe & Bar 西區推薦｜西區餐酒｜西區酒吧｜西區餐廳｜約會｜聚餐｜包場.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\黑帽爵士咖啡酒吧 BlackHatJazz cafe & Bar 西區推薦｜西區餐酒｜西區酒吧｜西區餐廳｜約會｜聚餐｜包場.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\196 Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\196 Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\A Glass or Two.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\A Glass or Two.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\A Light.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\A Light.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\Alchemy Bar Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Alchemy Bar Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\all_stores.csv
# 檢測到的編碼: UTF-8-SIG
# 檔案 D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\all_stores.csv 不包含 '評論' 欄位，跳過
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\attic trade company.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\attic trade company.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\Bar Edge.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Edge.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\信義區 酒吧\BAR HINOKI.csv
# 檢測到的編碼: UTF-8-SIG
# ...
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\灶咖 Zào Kā Bar & Bistro｜南京三民餐酒館｜饒河夜市｜推薦酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\玖杯 Κρασί 京華店.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\玖杯 Κρασί 京華店.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\異塵CELLAR LOUNGE BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\異塵CELLAR LOUNGE BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\祈駑南（cinunan）原住民餐酒館(酒吧）.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\祈駑南（cinunan）原住民餐酒館(酒吧）.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\莉莎精緻卡拉ok.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\莉莎精緻卡拉ok.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\西班牙小酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\西班牙小酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\覓 Trovin 餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\覓 Trovin 餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\角落酒吧The Corner One.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\角落酒吧The Corner One.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\貓 嗑睡 Cat Nap.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\貓 嗑睡 Cat Nap.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\貓下去敦北俱樂部.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\貓下去敦北俱樂部.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\買酒網 小巨蛋門市.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\買酒網 小巨蛋門市.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\酒塞子酒坊.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒塞子酒坊.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\酒與鮭魚日本酒專門_清酒、柚子酒、梅酒、優格酒「批發送禮」.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒與鮭魚日本酒專門_清酒、柚子酒、梅酒、優格酒「批發送禮」.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\金夫人美式居酒屋.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\金夫人美式居酒屋.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\閑閑餐酒館 YinYin Bistro.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\閑閑餐酒館 YinYin Bistro.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\青樓中式餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\青樓中式餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\松山區 酒吧\Ｗonder bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Ｗonder bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\98 酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\98 酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\all_stores.csv
# 檢測到的編碼: UTF-8-SIG
# 檔案 D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\all_stores.csv 不包含 '評論' 欄位，跳過
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Ark Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Ark Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\AWT Bistro下班後餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\AWT Bistro下班後餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Bar Stardust 星塵.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Bar Stardust 星塵.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Barchef Taipei _ 西門町酒吧 _ 水煙館 _ 咖哩飯｜台北推薦酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Barchef Taipei _ 西門町酒吧 _ 水煙館 _ 咖哩飯｜台北推薦酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\BearJunkies熊飲（早午餐＆酒吧）.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\BearJunkies熊飲（早午餐＆酒吧）.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\CASA Cafe & Bar Taipei （城堡）.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\CASA Cafe & Bar Taipei （城堡）.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Chance Cafe & Bar 無心戒酒互助會 - 成都分會.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Chance Cafe & Bar 無心戒酒互助會 - 成都分會.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Driftwood 西門町.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Driftwood 西門町.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Drunk Shelter Hanko 西門駐唱酒吧｜特色調酒｜live music｜live band 酒吧｜熱門｜人氣｜必訪｜現場音樂酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Drunk Shelter Hanko 西門駐唱酒吧｜特色調酒｜live music｜live band 酒吧｜熱門｜人氣｜必訪｜現場音樂酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\DRUNK Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\DRUNK Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Fancy Bar Ximen _ 西門推薦酒吧-台北萬華西門町餐酒館_酒吧_調酒 慶生_約會_包場_派對_聚會 深夜酒吧_創意料理_網美酒吧 2024人氣打卡推薦 必去訂位好評 西門捷運站_藍線_綠線 PTT Dcard.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Fancy Bar Ximen _ 西門推薦酒吧-台北萬華西門町餐酒館_酒吧_調酒 慶生_約會_包場_派對_聚會 深夜酒吧_創意料理_網美酒吧 2024人氣打卡推薦 必去訂位好評 西門捷運站_藍線_綠線 PTT Dcard.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\G CLUB TAIPEI.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\G CLUB TAIPEI.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Geography Bar&Restaurant 台灣環島調酒 Taiwan-inspired Cocktails.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Geography Bar&Restaurant 台灣環島調酒 Taiwan-inspired Cocktails.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\HANKO 60 如醉如夢.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\HANKO 60 如醉如夢.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\HEY BRO Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\HEY BRO Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\I Miss覓室_台北酒吧 西門酒吧 Ximending Bar 西門町バー 시먼 딩 바 台北DJ SHOW.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\I Miss覓室_台北酒吧 西門酒吧 Ximending Bar 西門町バー 시먼 딩 바 台北DJ SHOW.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\kani kani cafe&bar餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\kani kani cafe&bar餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\KHouse 化學實驗室.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\KHouse 化學實驗室.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Last Order 餐酒館.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Last Order 餐酒館.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\LION BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\LION BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Locker Room.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Locker Room.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\N.one BAR.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\N.one BAR.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Nonsense Bar 無心戒酒互助會 - 武昌分會.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Nonsense Bar 無心戒酒互助會 - 武昌分會.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\ONCE Cafe&Bar 無心戒酒互助會-西寧分會.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\ONCE Cafe&Bar 無心戒酒互助會-西寧分會.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\PawBar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\PawBar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\RayDarts.Taipei bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\RayDarts.Taipei bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\The 58 Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The 58 Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\THE BED Ximen.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\THE BED Ximen.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\THE garden.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\THE garden.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\THE HOLE mini bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\THE HOLE mini bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\The park J.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\The park J.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Westland Bar&Bistro｜深夜酒吧.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Westland Bar&Bistro｜深夜酒吧.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\Wishy Lounge Bar 慾室.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\Wishy Lounge Bar 慾室.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\冰茶專賣店 Iced Tea Shop.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\冰茶專賣店 Iced Tea Shop.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\尖叫 雞翅 Wings & Fries 雞翅酒吧 _ 雞翅吃到飽｜西門餐酒館｜Chicken Wings Beer Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\尖叫 雞翅 Wings & Fries 雞翅酒吧 _ 雞翅吃到飽｜西門餐酒館｜Chicken Wings Beer Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\巧軒飲室 CH Draft Room ｜Coffee&Ccocktail BAR｜咖啡廳｜酒吧｜手沖咖啡｜雞尾酒｜無酒精調飲｜啤酒｜私廚｜活動包場｜.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\巧軒飲室 CH Draft Room ｜Coffee&Ccocktail BAR｜咖啡廳｜酒吧｜手沖咖啡｜雞尾酒｜無酒精調飲｜啤酒｜私廚｜活動包場｜.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\巷內酒吧 x 酒 鬼煙醉.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\巷內酒吧 x 酒 鬼煙醉.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\灰色可樂 創始店(NO.1)Grey Cola Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\灰色可樂 創始店(NO.1)Grey Cola Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\烏托邦 Utopia Taipei.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\烏托邦 Utopia Taipei.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\無名Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\無名Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\無向 Bar Without Ximen.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\無向 Bar Without Ximen.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\燈亮有酒 Light Up Bar 【試營運】【西門．萬華】(酒吧，酒吧推薦，特色酒吧，平價酒吧，調酒).csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\燈亮有酒 Light Up Bar 【試營運】【西門．萬華】(酒吧，酒吧推薦，特色酒吧，平價酒吧，調酒).png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\獅鬥cdou bar _ 西門酒吧 台北港式餐酒館 深夜酒吧 _ Late-night bar บาร์กลางคืน 深夜バー 심야 바.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\獅鬥cdou bar _ 西門酒吧 台北港式餐酒館 深夜酒吧 _ Late-night bar บาร์กลางคืน 深夜バー 심야 바.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\竹Ta.ke 九龍灣會館 kowloonbay Shisha.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\竹Ta.ke 九龍灣會館 kowloonbay Shisha.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\老城西。酒食製作所.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\老城西。酒食製作所.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\西門紅樓露天酒吧區.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\西門紅樓露天酒吧區.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\解鎖 JOYSOUL Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\解鎖 JOYSOUL Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\追夢人DISCO｜西門.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\追夢人DISCO｜西門.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\酒咖飲冰室 JIU KA Bistro & Bar.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒咖飲冰室 JIU KA Bistro & Bar.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\酒肆西門 Ximen Beer Bar - 西門町酒吧 ｜台北酒吧推薦 Taipei Bar _ Craft Beer _ Whisky _ Shochu _ Cider.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\酒肆西門 Ximen Beer Bar - 西門町酒吧 ｜台北酒吧推薦 Taipei Bar _ Craft Beer _ Whisky _ Shochu _ Cider.png
# 處理檔案: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\萬華區 酒吧\鹿境早午餐 & 餐酒館_西門Arrival Brunch & Bistro (原 滷餐小酒館Zoo Bistro) ｜餐酒 _西門美食｜早午餐 ｜ 宵夜-萬華人氣早午餐_西門必吃早午餐_在地推薦早午餐_外帶漢堡_外帶早午餐_人氣餐廳_推薦早午餐.csv
# 檢測到的編碼: UTF-8-SIG
# 已儲存文字雲圖片至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud\鹿境早午餐 & 餐酒館_西門Arrival Brunch & Bistro (原 滷餐小酒館Zoo Bistro) ｜餐酒 _西門美食｜早午餐 ｜ 宵夜-萬華人氣早午餐_西門必吃早午餐_在地推薦早午餐_外帶漢堡_外帶早午餐_人氣餐廳_推薦早午餐.png
# 所有酒吧的文字雲關鍵字數據已儲存至: D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論\wordcloud.csv
# 以下店家沒有生成文字雲圖片:
# wordcloud
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores

# %%
import os

# 主資料夾路徑
main_folder_path = "D:/YU_LAB_Project_group2/Project-of-group-2/new_code/酒吧評論"
output_folder_path = os.path.join(main_folder_path, "wordcloud")  # 文字雲圖片存放的資料夾

# 獲取所有 CSV 檔案的店家名稱（去掉 .csv 副檔名，忽略特定文件）
csv_files = [
    os.path.splitext(file)[0] for root, dirs, files in os.walk(main_folder_path)
    for file in files if file.endswith(".csv") and file != "all_store.csv"
]

# 獲取所有已生成文字雲圖片的店家名稱（去掉 .png 副檔名）
if os.path.exists(output_folder_path):
    image_files = [
        os.path.splitext(file)[0] for file in os.listdir(output_folder_path)
        if file.endswith(".png")
    ]
else:
    image_files = []

# 計算總店家數
total_stores = len(csv_files)

# 找出未生成文字雲圖片的店家
missing_images = [bar for bar in csv_files if bar not in image_files]

# 輸出結果
print(f"總共有 {total_stores} 家店家。")
if missing_images:
    print(f"其中有 {len(missing_images)} 家店家沒有生成文字雲圖片:")
    for bar in missing_images:
        print(bar)
else:
    print("所有店家都已生成文字雲圖片。")
# Out:
# 總共有 830 家店家。
# 其中有 13 家店家沒有生成文字雲圖片:
# wordcloud
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
# all_stores
